# %% [markdown]
# # Примеры для задачи 3

# %%
# Пример 1: p(x) = x^3 - 6 x^2 + 11 x - 6  (корни 1, 2, 3)
1 -6 11 -6

# Пример 2: p(x) = x^3 - x  (корни -1, 0, 1)
1 0 -1 0

# Пример 3: p(x) = (x - 1)^3  (кратный корень 1 кратности 3)
1 -3 3 -1

# Пример 4: p(x) = x^4 - 5 x^2 + 4  (корни -2, -1, 1, 2)
1 0 -5 0 4

# Пример 5: p(x) = x^2 + 1  (действительных корней нет)
1 0 1

# Пример 6: многочлен степени 5 
1 -2 -5 6 3 0

# Пример 7: 
1 -3 2 1 -4 2 -1

# Пример 8: 
2 -1 -5 3 4 -2 -1 1
