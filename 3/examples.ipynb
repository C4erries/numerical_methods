# %% [markdown]
# # Примеры для задачи 3

# %%
# Пример 1: p(x) = x^3 - 6 x^2 + 11 x - 6  (корни 1, 2, 3)
1 -6 11 -6

# Пример 2: p(x) = x^4 - 102 x^3 + 199x^2 + 102x - 200
# (корни 100, 2, 1, -1) Явно доминирующий корень
1 -102 199 102 -200

# Пример 3: p(x) = (x - 2)^3  (кратный корень 2 кратности 3)
# py main.py --max-iter-ratio 1000000 --tol-ratio 1e-5 --multiple-roots
1 -6 12 -8

# Пример 4: p(x) = x^4 - 5 x^2 + 4  (корни -2, -1, 1, 2)
1 0 -5 0 4
    
# Пример 5: p(x) = x^2 + 1  (действительных корней нет)
1 0 1

# Пример 6: p(x) = x^4 - 76.8x^3 + 112.8625x^2 + 287.56875x - 263.375
# (75.25, 2.5, -1.75, 0.8)
1 -76.8 112.8625 287.56875 -263.375
